# %% [markdown]
# # Generating a distorted mesh using a square mesh

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../../'))

import numpy as np
from matplotlib import pyplot as plt

from dg_maxwell import params
from dg_maxwell import msh_parser
from dg_maxwell import lagrange

plt.rcParams['figure.figsize']     = 12, 7.5
plt.rcParams['lines.linewidth']    = 1.5
plt.rcParams['font.family']        = 'serif'
plt.rcParams['font.weight']        = 'bold'
plt.rcParams['font.size']          = 20  
plt.rcParams['font.sans-serif']    = 'serif'
plt.rcParams['text.usetex']        = True
plt.rcParams['axes.linewidth']     = 1.5
plt.rcParams['axes.titlesize']     = 'medium'
plt.rcParams['axes.labelsize']     = 'medium'

plt.rcParams['xtick.major.size']   = 8
plt.rcParams['xtick.minor.size']   = 4
plt.rcParams['xtick.major.pad']    = 8
plt.rcParams['xtick.minor.pad']    = 8
plt.rcParams['xtick.color']        = 'k'
plt.rcParams['xtick.labelsize']    = 'medium'
plt.rcParams['xtick.direction']    = 'in'    

plt.rcParams['ytick.major.size']   = 8
plt.rcParams['ytick.minor.size']   = 4
plt.rcParams['ytick.major.pad']    = 8
plt.rcParams['ytick.minor.pad']    = 8
plt.rcParams['ytick.color']        = 'k'
plt.rcParams['ytick.labelsize']    = 'medium'
plt.rcParams['ytick.direction']    = 'in'
plt.rcParams['text.usetex']        = True
plt.rcParams['text.latex.unicode'] = True
# Out:
# gmshtranslator friendly reminder: rules and actions prototypes
#
#
# def node_condition(tag,x,y,z,physgroups):
# def node_action(tag,x,y,z):
# def element_condition(eletag,eletype,physgrp,nodes):
# def element_action(eletag,eletype,physgrp,nodes):

# %% [markdown]
# ## 1. Generate a regular $N \times N$ mesh file and read it using mesh parser.

# %%
# This function reads the mesh
nodes, elements = msh_parser.read_order_2_msh('mesh/square_contiguous.msh')
# Out:
# gmshTranslator: Initializing...
# gmshTranslator: Mesh has 441 nodes.
# gmshTranslator: Mesh has 144 elements.
# gmshTranslator: Processed 589 lines.
# gmshTranslator: There are 1 physical groups available:
# gmshTranslator:      > 0
# gmshTranslator: Parsing nodes
# gmshTranslator: Parsing elements
# gmshTranslator: No rules for elements... skipping elements.
# gmshTranslator: Parsing nodes
# gmshTranslator: No rules for nodes... skipping nodes.
# gmshTranslator: Parsing elements

# %%
N_LGL = 8
xi_LGL  = np.array(lagrange.LGL_points(N_LGL))
eta_LGL = np.array(lagrange.LGL_points(N_LGL))
# Out:
# /home/rishabh/anaconda3/lib/python3.6/site-packages/numpy/lib/polynomial.py:1193: FutureWarning: In the future extra properties will not be copied across when constructing one poly1d from another
#   other = poly1d(other)
# /home/rishabh/anaconda3/lib/python3.6/site-packages/numpy/lib/polynomial.py:1220: FutureWarning: In the future extra properties will not be copied across when constructing one poly1d from another
#   other = poly1d(other)

# %% [markdown]
# ## 2. Plot the original mesh.

# %%
axes_handler = plt.axes()


msh_parser.plot_mesh_grid(nodes, elements, xi_LGL, eta_LGL,
                          axes_handler, plot_LGL_grid = False,
                          print_element_tag = True)

plt.title(r'Plot of Mesh. The element tag is shown in red')
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')

plt.xlim(-1.1, 1.1)
plt.ylim(-1.1, 1.1)
plt.axes().set_aspect('equal')

# plt.savefig('square.png')
plt.show()
# Out:
# gmshTranslator: Ending
# /home/rishabh/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## 3. Write a distortion function which will distort the internal nodes of the square mesh.

# %%
def function(x):
#    return 0.07 * np.sin(2 * np.pi * x)
     return 0.07 * x

# %%
def function2(x):
    return 0.035*x

# %%
def function3(x):
    return 0.035*x

# %% [markdown]
# ## 4. The $\xi$ coordinates of the internal nodes of the mesh will be modulated by varying function($\eta$).
# ## 5. The $\eta$ coordinates of the internal nodes of the mesh will be modulated by varying function($\xi$).

# %%
# For parallelograms in square mesh

new_nodes = nodes.copy()

for node_tag, node in enumerate(nodes):
    if np.all((np.abs(node - [-0.8, 0.8])<1e-10)) or np.all(np.abs(node - [-0.8, -0.8])<1e-10) or np.all(np.abs(node - [0.8, -0.8])<1e-10) or np.all(np.abs(node - [0.8, 0.8])<1e-10):
       print(node, '\t vertex')
       continue
        
#     if ((abs(node[1]-(-0.9))<1e-10) or (abs(node[1]-(0.9))<1e-10)): 
#         new_nodes[node_tag, 1] += function2(node[0])
       
#     if ((abs(node[0]-(-0.9))<1e-10)) or (abs(node[0]-(0.9))<1e-10) :
#         new_nodes[node_tag, 0] += function2(node[1])
   
    if ((node[1] > -0.69) and (node[1] < 0.69) and (node[0] >-0.69) and (node[0] < 0.69)):
        new_nodes[node_tag, 1] += function(node[0])
        new_nodes[node_tag, 0] += function(node[1])
        continue
        
#     if ((abs(node[0]) >0.79) and (abs(node[0]) < 0.81) and (node[1]) >-0.81) and ((node[1]) < 0.81):
#         new_nodes[node_tag, 1] += function(node[0])
#         continue
        
#     if ((abs(node[1]) >0.79) and (abs(node[1]) < 0.81) and (node[0]) >-0.81) and ((node[0]) < 0.81):
#         new_nodes[node_tag, 0] += function(node[1])
#         continue
        
    if ((abs(node[0]) >0.69) and (abs(node[0]) < 0.71) and (node[1]) >-0.75) and ((node[1]) < 0.75):
        new_nodes[node_tag, 1] += function3(node[0])
        new_nodes[node_tag, 0] += function2(node[1])
        continue
        
    if ((abs(node[1]) >0.69) and (abs(node[1]) < 0.71) and (node[0]) >-0.75) and ((node[0]) < 0.75):
        new_nodes[node_tag, 0] += function3(node[1])
        new_nodes[node_tag, 1] += function2(node[0])
        continue
        
#     if ((abs(node[1]) >0.89) and (abs(node[1]) < 0.91) and (node[0]) >-0.75) and ((node[0]) < 0.75):
#         new_nodes[node_tag, 0] += function2(node[1])
#         continue
        
#     if (((node[1]) > 0.79) and ((node[1]) < 0.80)):
#         new_nodes[node_tag, 0] += function(node[1])

#     if ((node[0] >-0.81) and (node[0] < 0.81)):
#         new_nodes[node_tag, 0] += function(node[1])
 #   if ((node[0] >-0.59 ) and (node[0] < 0.59)):
  #      new_nodes[node_tag, 0] += function(node[1])
# Out:
# [-0.8  0.8] 	 vertex
# [ 0.8  0.8] 	 vertex
# [-0.8 -0.8] 	 vertex
# [ 0.8 -0.8] 	 vertex
# -0.7
# -0.599999999999
# -0.699999999999
# -0.399999999999
# -0.499999999999
# -0.199999999998
# -0.299999999999
# 1.92515448028e-12
# -0.0999999999983
# 0.200000000002
# 0.100000000002
# 0.400000000001
# 0.300000000001
# 0.600000000001
# 0.500000000001
# 0.7
# 0.700000000001
# -0.7
# -0.7
# 0.7
# 0.7
# -0.7
# -0.7
# 0.7
# 0.7
# -0.7
# -0.7
# 0.7
# 0.7
# -0.7
# -0.7
# 0.7
# 0.7
# -0.7
# -0.7
# 0.7
# 0.7
# -0.7
# -0.7
# 0.7
# 0.7
# -0.600000000001
# -0.700000000001
# -0.400000000001
# -0.500000000001
# -0.200000000002
# -0.300000000001
# -1.92516141917e-12
# -0.100000000002
# 0.199999999998
# 0.0999999999983
# 0.399999999999
# 0.299999999999
# 0.599999999999
# 0.499999999999
# 0.699999999999

# %% [markdown]
# ## 6. The new nodes can be accessed from the variable `new_nodes`. Use this variable instead of `nodes` variable from now on. Everything else will remain the same.

# %% [markdown]
# ## 7. Plot the mesh

# %%
axes_handler = plt.axes()


msh_parser.plot_mesh_grid(new_nodes, elements, xi_LGL, eta_LGL,
                          axes_handler, plot_LGL_grid = True,
                          print_element_tag = False)

# plt.title(r'Grid plot of a mesh for $N_{LGL} = 8$.'
#           '\n Red lines are mesh grid, and \n'
#           'blue lines are element boundaries.')
# plt.title(r'Plot of Mesh. The element tag is shown in red')
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')

plt.xlim(-1.1, 1.1)
plt.ylim(-1.1, 1.1)
plt.axes().set_aspect('equal')

plt.savefig('square.png')
plt.show()
# Out:
# /home/rishabh/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
